# %% [markdown]
# # Análise Exploratória de Dados

# %%
import yfinance as yf

# %%
symbols = ['PETR4.SA', 'VALE3.SA']

# %%
df = yf.download(symbols, start='2018-01-01', end='2024-07-20')
# Out:
# /var/folders/_1/d2zyjv_j10g4t6lc3n4mc5k00000gn/T/ipykernel_66410/1577215499.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbols, start='2018-01-01', end='2024-07-20')
# [*********************100%***********************]  2 of 2 completed

# %%
df
# Out:
# Price           Close                  High                   Low             \
# Ticker       PETR4.SA   VALE3.SA   PETR4.SA   VALE3.SA   PETR4.SA   VALE3.SA
# Date
# 2018-01-02   4.949027  23.603914   4.949027  23.615230   4.841375  22.879728
# 2018-01-03   4.993883  23.462477   4.999863  23.694442   4.895202  23.366295
# 2018-01-04   5.002854  23.558651   5.071632  23.971663   4.969960  23.490759
# 2018-01-05   5.032757  23.926401   5.041728  23.926401   4.955008  23.371947
# 2018-01-08   5.092564  24.458229   5.092564  24.458229   4.996872  23.988641
# ...               ...        ...        ...        ...        ...        ...
# 2024-07-15  34.950317  57.969910  35.159111  58.144766  34.677978  57.445334
# 2024-07-16  34.859535  57.362514  34.950314  57.371716  34.596272  56.479021
# 2024-07-17  35.041096  56.828735  35.122798  57.077218  34.805069  56.672285
# 2024-07-18  34.977547  56.294956  35.095562  56.975982  34.814142  56.193726
# ...

# %%
df['Close'].plot()
df.isna().sum()
df.describe()
# Out:
# Price         Close                      High                       Low  \
# Ticker     PETR4.SA     VALE3.SA     PETR4.SA     VALE3.SA     PETR4.SA
# count   1626.000000  1626.000000  1626.000000  1626.000000  1626.000000
# mean      13.261113    47.982526    13.447697    48.583723    13.069159
# std        8.397204    16.885600     8.474273    17.062710     8.305521
# min        3.638940    20.606258     3.925802    21.669809     3.497121
# 25%        7.590705    30.381722     7.727502    30.849257     7.465788
# 50%        9.343072    54.330303     9.457771    54.977485     9.218808
# 75%       16.356034    61.029555    16.657972    61.825479    16.146643
# max       36.780144    79.544838    37.150862    79.780226    36.638919
#
# Price                       Open                     Volume
# Ticker     VALE3.SA     PETR4.SA     VALE3.SA      PETR4.SA      VALE3.SA
# count   1626.000000  1626.000000  1626.000000  1.626000e+03  1.626000e+03
# ...

# %%
df.columns
# Out:
# MultiIndex([( 'Close', 'PETR4.SA'),
#             ( 'Close', 'VALE3.SA'),
#             (  'High', 'PETR4.SA'),
#             (  'High', 'VALE3.SA'),
#             (   'Low', 'PETR4.SA'),
#             (   'Low', 'VALE3.SA'),
#             (  'Open', 'PETR4.SA'),
#             (  'Open', 'VALE3.SA'),
#             ('Volume', 'PETR4.SA'),
#             ('Volume', 'VALE3.SA')],
#            names=['Price', 'Ticker'])
